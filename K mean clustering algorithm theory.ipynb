# %% [markdown]
# # What is K mean clustering algorithm

# %%
1] K-Means Clustering is an unsupervised learning algorithm that is used to solve the clustering problems in ML or data science.

2] which groups the unlabeled dataset into different clusters. 
   Here K defines the number of pre-defined clusters that need to be created in the process,as if 
    K=2, there will be two clusters, and for K=3, there will be three clusters, and so on.
    
3] It allows us to cluster the data into different groups and a convenient way to discover the categories of groups
   in the unlabeled dataset on its own without the need for any training.
    
4] The k-means clustering algorithm mainly performs two tasks:
    
    4.1] Determines the best value for K center points or centroids by an iterative process.
   
    4.2] Assigns each data point to its closest k-center. Those data points which are near to the particular k-center, 
         create a cluster.

# %% [markdown]
# ![Screenshot%202024-08-21%20040227.png](attachment:Screenshot%202024-08-21%20040227.png)

# %% [markdown]
# # In problem statement if they have given the mean then u can use .if not then u have to find mean. As u see Ex. below

# %% [markdown]
# ![Screenshot%202024-08-21%20033700.png](attachment:Screenshot%202024-08-21%20033700.png)

# %%
There is Two Strategies for above example

1] Eculidean distance

# %% [markdown]
# ![Eculidean%20distance%20formula.png](attachment:Eculidean%20distance%20formula.png)

# %%
2] U can pick any two no.from datasets & keep group 1 as set (k1) annd another group (k2) 

   u can differntiate these group by keeping closest no. as set of one group
    
once the group is done Add them all n divide by the counting of no.present in group (average)
and after that u will get a no. then follow the same (keeping closest no. as set of one group),(average)

keep doing these until u will get same no. repeating
